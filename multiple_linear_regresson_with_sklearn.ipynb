# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("D:/courses/[FreeCourseSite.com] Udemy - The Data Science Course Complete Data Science Bootcamp/34 - Advanced Statistical Methods - Linear Regression with sklearn/007 1.02.Multiple-linear-regression.csv")
data
# Out:
#      SAT  Rand 1,2,3   GPA
# 0   1714           1  2.40
# 1   1664           3  2.52
# 2   1760           3  2.54
# 3   1685           3  2.74
# 4   1693           2  2.83
# ..   ...         ...   ...
# 79  1936           3  3.71
# 80  1810           1  3.71
# 81  1987           3  3.73
# 82  1962           1  3.76
# 83  2050           2  3.81
#
# [84 rows x 3 columns]

# %%
y = data["GPA"]
x = data[["SAT","Rand 1,2,3"]]

# %%
reg = LinearRegression()
reg.fit(x,y)    #ml was done here
# Out:
# LinearRegression()

# %%
reg.score(x, y) #tells R^2 (tells how accurate is dependent variable is from independent variables, the higher the better)
# Out:
# 0.4066811952814283
